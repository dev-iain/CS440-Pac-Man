# %%
# %run autograder.py
# Out:
# Starting on 9-9 at 18:13:10
#
# Question q1
# ...
# *** Method not implemented: depthFirstSearch at line 93 of c:\Users\nicol\OneDrive\Documents\Fall 2026\CS440-Pac-Man\search.py
# *** FAIL: Terminated with a string exception.
#
# ### Question q1: 0/3 ###
#
#
# Question q2
# ...
# *** Method not implemented: breadthFirstSearch at line 98 of c:\Users\nicol\OneDrive\Documents\Fall 2026\CS440-Pac-Man\search.py
# *** FAIL: Terminated with a string exception.
#
# ### Question q2: 0/3 ###
#
#
# Question q3
# ...
# *** Method not implemented: uniformCostSearch at line 103 of c:\Users\nicol\OneDrive\Documents\Fall 2026\CS440-Pac-Man\search.py
# *** FAIL: Terminated with a string exception.
#
# ### Question q3: 0/3 ###
#
#
# Question q4
# ...
# *** Method not implemented: aStarSearch at line 115 of c:\Users\nicol\OneDrive\Documents\Fall 2026\CS440-Pac-Man\search.py
# *** FAIL: Terminated with a string exception.
#
# ### Question q4: 0/3 ###
#
#
# Question q5
# ...
